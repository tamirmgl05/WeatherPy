# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 752

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):

   
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    city_url = url + "&q=" + city.replace(" ","+")

  
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    record_count += 1

    try:
     
        city_weather = requests.get(city_url).json()
      
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_conditions = city_weather["weather"][0]["description"]
       
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_conditions,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})


    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | faanui
# Processing Record 6 of Set 1 | gaya
# Processing Record 7 of Set 1 | acarau
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | bengkulu
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | sao felix do xingu
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | morehead
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | gilgit
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | huanren
# Processing Record 20 of Set 1 | clyde river
# Processing Record 21 of Set 1 | gambela
# Processing Record 22 of Set 1 | oranjestad
# Processing Record 23 of Set 1 | baiyin
# Processing Record 24 of Set 1 | itarema
# Processing Record 25 of Set 1 | ridgecrest
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | ballina
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | nandyal
# Processing Record 32 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 1 | adrar
# Processing Record 34 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 35 of Set 1 | slave lake
# Processing Record 36 of Set 1 | bemidji
# Processing Record 37 of Set 1 | te anau
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | sola
# Processing Record 40 of Set 1 | kenai
# Processing Record 41 of Set 1 | rawlins
# Processing Record 42 of Set 1 | meulaboh
# Processing Record 43 of Set 1 | smithers
# Processing Record 44 of Set 1 | camalu
# Processing Record 45 of Set 1 | siddapur
# Processing Record 46 of Set 1 | srednekolymsk
# Processing Record 47 of Set 1 | novikovo
# Processing Record 48 of Set 1 | manzil jamil
# City not found. Skipping...
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | hellin
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | vagay
# Processing Record 6 of Set 2 | hirara
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | sitka
# Processing Record 9 of Set 2 | juifang
# City not found. Skipping...
# Processing Record 10 of Set 2 | nemuro
# Processing Record 11 of Set 2 | penzance
# Processing Record 12 of Set 2 | viedma
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | flinders
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | chiang khong
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | sisimiut
# Processing Record 19 of Set 2 | abu zabad
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | oussouye
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | geraldton
# Processing Record 26 of Set 2 | san andres
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | okhotsk
# Processing Record 29 of Set 2 | basco
# Processing Record 30 of Set 2 | raudeberg
# Processing Record 31 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 2 | godda
# Processing Record 33 of Set 2 | kingston upon hull
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | rakiv lis
# Processing Record 36 of Set 2 | rocha
# Processing Record 37 of Set 2 | dingle
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | kangaatsiaq
# Processing Record 44 of Set 2 | strezhevoy
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | lagos
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | deputatskiy
# Processing Record 50 of Set 2 | san quintin
# Processing Record 1 of Set 3 | camana
# Processing Record 2 of Set 3 | porto murtinho
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | victoria
# Processing Record 6 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | tagusao
# Processing Record 9 of Set 3 | ahipara
# Processing Record 10 of Set 3 | morgan city
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | vallenar
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | kattivakkam
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 3 | bambous virieux
# Processing Record 18 of Set 3 | valentin gomez farias
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | tura
# Processing Record 21 of Set 3 | airai
# Processing Record 22 of Set 3 | korla
# Processing Record 23 of Set 3 | lima
# Processing Record 24 of Set 3 | vangaindrano
# Processing Record 25 of Set 3 | mataura
# Processing Record 26 of Set 3 | alice springs
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | gainesville
# Processing Record 29 of Set 3 | yellowknife
# Processing Record 30 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 3 | cidreira
# Processing Record 32 of Set 3 | paamiut
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | carnarvon
# Processing Record 35 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 3 | mar del plata
# Processing Record 37 of Set 3 | nurota
# Processing Record 38 of Set 3 | kangundo
# Processing Record 39 of Set 3 | pacific grove
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | dudinka
# Processing Record 42 of Set 3 | jutai
# Processing Record 43 of Set 3 | cayenne
# Processing Record 44 of Set 3 | sawtell
# Processing Record 45 of Set 3 | kudahuvadhoo
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | tsybuliv
# Processing Record 48 of Set 3 | sapao
# City not found. Skipping...
# Processing Record 49 of Set 3 | lavrentiya
# Processing Record 50 of Set 3 | vila franca do campo
# Processing Record 1 of Set 4 | neiafu
# Processing Record 2 of Set 4 | grants pass
# Processing Record 3 of Set 4 | constitucion
# Processing Record 4 of Set 4 | ostrovnoy
# Processing Record 5 of Set 4 | gravdal
# Processing Record 6 of Set 4 | lata
# Processing Record 7 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 8 of Set 4 | touros
# Processing Record 9 of Set 4 | gazli
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | teya
# Processing Record 12 of Set 4 | atuona
# Processing Record 13 of Set 4 | barrow
# Processing Record 14 of Set 4 | mahebourg
# Processing Record 15 of Set 4 | codrington
# Processing Record 16 of Set 4 | roseburg
# Processing Record 17 of Set 4 | qasigiannguit
# Processing Record 18 of Set 4 | riyadh
# Processing Record 19 of Set 4 | ouallam
# Processing Record 20 of Set 4 | wenling
# Processing Record 21 of Set 4 | palu
# Processing Record 22 of Set 4 | comodoro rivadavia
# Processing Record 23 of Set 4 | benalla
# Processing Record 24 of Set 4 | kirakira
# Processing Record 25 of Set 4 | visby
# Processing Record 26 of Set 4 | gimli
# Processing Record 27 of Set 4 | ludvika
# Processing Record 28 of Set 4 | ferme-neuve
# Processing Record 29 of Set 4 | poco verde
# Processing Record 30 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 4 | polson
# Processing Record 32 of Set 4 | chuy
# Processing Record 33 of Set 4 | byumba
# Processing Record 34 of Set 4 | merauke
# Processing Record 35 of Set 4 | caruray
# Processing Record 36 of Set 4 | bambanglipuro
# Processing Record 37 of Set 4 | cherskiy
# Processing Record 38 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 4 | dali
# Processing Record 40 of Set 4 | poum
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | mao
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | najran
# Processing Record 45 of Set 4 | kavaratti
# Processing Record 46 of Set 4 | tigil
# Processing Record 47 of Set 4 | yar-sale
# Processing Record 48 of Set 4 | college
# Processing Record 49 of Set 4 | zhetysay
# Processing Record 50 of Set 4 | great yarmouth
# Processing Record 1 of Set 5 | iqaluit
# Processing Record 2 of Set 5 | omsukchan
# Processing Record 3 of Set 5 | chumikan
# Processing Record 4 of Set 5 | alyangula
# Processing Record 5 of Set 5 | sterling
# Processing Record 6 of Set 5 | kota kinabalu
# Processing Record 7 of Set 5 | lompoc
# Processing Record 8 of Set 5 | khani
# Processing Record 9 of Set 5 | aklavik
# Processing Record 10 of Set 5 | kahului
# Processing Record 11 of Set 5 | kulhudhuffushi
# Processing Record 12 of Set 5 | saint george
# Processing Record 13 of Set 5 | kirkwall
# Processing Record 14 of Set 5 | kavieng
# Processing Record 15 of Set 5 | dumas
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | salalah
# Processing Record 18 of Set 5 | butterworth
# Processing Record 19 of Set 5 | half moon bay
# Processing Record 20 of Set 5 | vao
# Processing Record 21 of Set 5 | bonthe
# Processing Record 22 of Set 5 | shingu
# Processing Record 23 of Set 5 | el alto
# Processing Record 24 of Set 5 | port hedland
# Processing Record 25 of Set 5 | bilibino
# Processing Record 26 of Set 5 | san juan de la maguana
# Processing Record 27 of Set 5 | pisco
# Processing Record 28 of Set 5 | polunochnoye
# Processing Record 29 of Set 5 | mayo
# Processing Record 30 of Set 5 | vossevangen
# Processing Record 31 of Set 5 | coihaique
# Processing Record 32 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 5 | castro
# Processing Record 34 of Set 5 | afyonkarahisar
# Processing Record 35 of Set 5 | bredasdorp
# Processing Record 36 of Set 5 | haines junction
# Processing Record 37 of Set 5 | empalme
# Processing Record 38 of Set 5 | sidi ali
# Processing Record 39 of Set 5 | west bay
# Processing Record 40 of Set 5 | severo-kurilsk
# Processing Record 41 of Set 5 | pevek
# Processing Record 42 of Set 5 | westport
# Processing Record 43 of Set 5 | taft
# Processing Record 44 of Set 5 | santa cruz
# Processing Record 45 of Set 5 | port angeles
# Processing Record 46 of Set 5 | tual
# Processing Record 47 of Set 5 | vitim
# Processing Record 48 of Set 5 | bandarbeyla
# Processing Record 49 of Set 5 | den helder
# Processing Record 50 of Set 5 | avarua
# Processing Record 1 of Set 6 | valpoi
# Processing Record 2 of Set 6 | kushima
# Processing Record 3 of Set 6 | sao filipe
# Processing Record 4 of Set 6 | shimoda
# Processing Record 5 of Set 6 | serafimovich
# Processing Record 6 of Set 6 | lumeje
# Processing Record 7 of Set 6 | leominster
# Processing Record 8 of Set 6 | micheweni
# Processing Record 9 of Set 6 | popondetta
# Processing Record 10 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 6 | havoysund
# Processing Record 12 of Set 6 | puerto escondido
# Processing Record 13 of Set 6 | manokwari
# Processing Record 14 of Set 6 | heihe
# Processing Record 15 of Set 6 | kalmunai
# Processing Record 16 of Set 6 | hasaki
# Processing Record 17 of Set 6 | mercedes
# Processing Record 18 of Set 6 | kuytun
# Processing Record 19 of Set 6 | almeirim
# Processing Record 20 of Set 6 | sosua
# Processing Record 21 of Set 6 | christchurch
# Processing Record 22 of Set 6 | port augusta
# Processing Record 23 of Set 6 | coro
# Processing Record 24 of Set 6 | gollere
# City not found. Skipping...
# Processing Record 25 of Set 6 | ulaanbaatar
# Processing Record 26 of Set 6 | nome
# Processing Record 27 of Set 6 | naze
# Processing Record 28 of Set 6 | carutapera
# Processing Record 29 of Set 6 | saldanha
# Processing Record 30 of Set 6 | ambulu
# Processing Record 31 of Set 6 | mino
# Processing Record 32 of Set 6 | chifeng
# Processing Record 33 of Set 6 | arlit
# Processing Record 34 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 6 | nizhniy tsasuchey
# Processing Record 36 of Set 6 | coquimbo
# Processing Record 37 of Set 6 | pindushi
# Processing Record 38 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 6 | ust-ishim
# Processing Record 40 of Set 6 | kamina
# Processing Record 41 of Set 6 | tuatapere
# Processing Record 42 of Set 6 | hermiston
# Processing Record 43 of Set 6 | cabo san lucas
# Processing Record 44 of Set 6 | obo
# Processing Record 45 of Set 6 | norman wells
# Processing Record 46 of Set 6 | ust-nera
# Processing Record 47 of Set 6 | nanakuli
# Processing Record 48 of Set 6 | ozinki
# Processing Record 49 of Set 6 | gazni
# City not found. Skipping...
# Processing Record 50 of Set 6 | alofi
# Processing Record 1 of Set 7 | mapiripan
# Processing Record 2 of Set 7 | stornoway
# Processing Record 3 of Set 7 | balasheyka
# Processing Record 4 of Set 7 | axim
# Processing Record 5 of Set 7 | olovyannaya
# Processing Record 6 of Set 7 | coahuayana
# Processing Record 7 of Set 7 | ochakiv
# Processing Record 8 of Set 7 | olafsvik
# Processing Record 9 of Set 7 | kampong cham
# Processing Record 10 of Set 7 | vila velha
# Processing Record 11 of Set 7 | taoudenni
# Processing Record 12 of Set 7 | gashua
# Processing Record 13 of Set 7 | fortuna
# Processing Record 14 of Set 7 | puerto madryn
# Processing Record 15 of Set 7 | palomares
# Processing Record 16 of Set 7 | mount gambier
# Processing Record 17 of Set 7 | katsuura
# Processing Record 18 of Set 7 | miranda
# Processing Record 19 of Set 7 | walvis bay
# Processing Record 20 of Set 7 | khorramshahr
# Processing Record 21 of Set 7 | innisfail
# Processing Record 22 of Set 7 | port hawkesbury
# Processing Record 23 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 7 | bairiki
# Processing Record 25 of Set 7 | hassleholm
# Processing Record 26 of Set 7 | hamilton
# Processing Record 27 of Set 7 | hambantota
# Processing Record 28 of Set 7 | krasnyy yar
# Processing Record 29 of Set 7 | lorengau
# Processing Record 30 of Set 7 | hovd
# Processing Record 31 of Set 7 | metro
# Processing Record 32 of Set 7 | abonnema
# Processing Record 33 of Set 7 | ambon
# Processing Record 34 of Set 7 | hobyo
# Processing Record 35 of Set 7 | lazaro cardenas
# Processing Record 36 of Set 7 | samarai
# Processing Record 37 of Set 7 | luban
# Processing Record 38 of Set 7 | qinnan
# Processing Record 39 of Set 7 | ust-maya
# Processing Record 40 of Set 7 | novoagansk
# Processing Record 41 of Set 7 | galesong
# Processing Record 42 of Set 7 | sinnamary
# Processing Record 43 of Set 7 | arman
# Processing Record 44 of Set 7 | almaznyy
# Processing Record 45 of Set 7 | bilma
# Processing Record 46 of Set 7 | salta
# Processing Record 47 of Set 7 | baker city
# Processing Record 48 of Set 7 | astipalaia
# City not found. Skipping...
# Processing Record 49 of Set 7 | mandalgovi
# Processing Record 50 of Set 7 | goderich
# Processing Record 1 of Set 8 | zhigansk
# Processing Record 2 of Set 8 | sept-iles
# Processing Record 3 of Set 8 | luena
# Processing Record 4 of Set 8 | burica
# City not found. Skipping...
# Processing Record 5 of Set 8 | hvolsvollur
# Processing Record 6 of Set 8 | palmer
# Processing Record 7 of Set 8 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 8 of Set 8 | vostok
# Processing Record 9 of Set 8 | nouadhibou
# Processing Record 10 of Set 8 | ruteng
# Processing Record 11 of Set 8 | maniitsoq
# Processing Record 12 of Set 8 | dong hoi
# Processing Record 13 of Set 8 | syamzha
# Processing Record 14 of Set 8 | north bend
# Processing Record 15 of Set 8 | umm kaddadah
# Processing Record 16 of Set 8 | taltal
# Processing Record 17 of Set 8 | sturgeon bay
# Processing Record 18 of Set 8 | harer
# Processing Record 19 of Set 8 | gurupi
# Processing Record 20 of Set 8 | vilyuysk
# Processing Record 21 of Set 8 | vanavara
# Processing Record 22 of Set 8 | pangody
# Processing Record 23 of Set 8 | contai
# Processing Record 24 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 8 | gejiu
# Processing Record 26 of Set 8 | slupsk
# Processing Record 27 of Set 8 | nyurba
# Processing Record 28 of Set 8 | sao tome
# Processing Record 29 of Set 8 | aksarka
# Processing Record 30 of Set 8 | vardo
# Processing Record 31 of Set 8 | makakilo city
# Processing Record 32 of Set 8 | terney
# Processing Record 33 of Set 8 | tazovskiy
# Processing Record 34 of Set 8 | farafangana
# Processing Record 35 of Set 8 | zabaykalsk
# Processing Record 36 of Set 8 | avera
# Processing Record 37 of Set 8 | zhangye
# Processing Record 38 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 39 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 8 | hofn
# Processing Record 41 of Set 8 | leo
# Processing Record 42 of Set 8 | piacabucu
# Processing Record 43 of Set 8 | kysyl-syr
# Processing Record 44 of Set 8 | oistins
# Processing Record 45 of Set 8 | scarborough
# Processing Record 46 of Set 8 | opuwo
# Processing Record 47 of Set 8 | springbok
# Processing Record 48 of Set 8 | tomatlan
# Processing Record 49 of Set 8 | macapa
# Processing Record 50 of Set 8 | carahue
# Processing Record 1 of Set 9 | jawhar
# Processing Record 2 of Set 9 | yerbogachen
# Processing Record 3 of Set 9 | paucartambo
# City not found. Skipping...
# Processing Record 4 of Set 9 | moultrie
# Processing Record 5 of Set 9 | bonavista
# Processing Record 6 of Set 9 | boali
# Processing Record 7 of Set 9 | cody
# Processing Record 8 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 9 | waitati
# Processing Record 10 of Set 9 | thiers
# Processing Record 11 of Set 9 | grindavik
# Processing Record 12 of Set 9 | bathsheba
# Processing Record 13 of Set 9 | lakes entrance
# Processing Record 14 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 15 of Set 9 | babynino
# Processing Record 16 of Set 9 | sibu
# Processing Record 17 of Set 9 | catanzaro
# Processing Record 18 of Set 9 | batagay-alyta
# Processing Record 19 of Set 9 | rutland
# Processing Record 20 of Set 9 | zhoukou
# Processing Record 21 of Set 9 | tampin
# Processing Record 22 of Set 9 | yumen
# Processing Record 23 of Set 9 | sembakung
# Processing Record 24 of Set 9 | kaiyuan
# Processing Record 25 of Set 9 | richards bay
# Processing Record 26 of Set 9 | bumba
# Processing Record 27 of Set 9 | krasnoturansk
# Processing Record 28 of Set 9 | byron bay
# Processing Record 29 of Set 9 | horta
# Processing Record 30 of Set 9 | la seyne-sur-mer
# Processing Record 31 of Set 9 | ixtapa
# Processing Record 32 of Set 9 | namtsy
# Processing Record 33 of Set 9 | kletnya
# Processing Record 34 of Set 9 | tahoua
# Processing Record 35 of Set 9 | havre-saint-pierre
# Processing Record 36 of Set 9 | saint anthony
# Processing Record 37 of Set 9 | akyab
# Processing Record 38 of Set 9 | qaqortoq
# Processing Record 39 of Set 9 | ilulissat
# Processing Record 40 of Set 9 | auki
# Processing Record 41 of Set 9 | concarneau
# Processing Record 42 of Set 9 | bouna
# Processing Record 43 of Set 9 | maceio
# Processing Record 44 of Set 9 | abu samrah
# Processing Record 45 of Set 9 | kundgol
# Processing Record 46 of Set 9 | severka
# Processing Record 47 of Set 9 | hualmay
# Processing Record 48 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 9 | vanimo
# Processing Record 50 of Set 9 | muravlenko
# Processing Record 1 of Set 10 | sandakan
# Processing Record 2 of Set 10 | filomeno mata
# Processing Record 3 of Set 10 | vila
# Processing Record 4 of Set 10 | mehamn
# Processing Record 5 of Set 10 | shache
# Processing Record 6 of Set 10 | marzuq
# Processing Record 7 of Set 10 | pundaguitan
# Processing Record 8 of Set 10 | genhe
# Processing Record 9 of Set 10 | raga
# Processing Record 10 of Set 10 | losino-petrovskiy
# Processing Record 11 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 10 | klamath falls
# Processing Record 13 of Set 10 | aksha
# Processing Record 14 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 10 | balkhash
# Processing Record 16 of Set 10 | uppsala
# Processing Record 17 of Set 10 | padang
# Processing Record 18 of Set 10 | raozan
# City not found. Skipping...
# Processing Record 19 of Set 10 | mazulskiy
# City not found. Skipping...
# Processing Record 20 of Set 10 | medzev
# Processing Record 21 of Set 10 | troitskoye
# Processing Record 22 of Set 10 | kaura namoda
# Processing Record 23 of Set 10 | otane
# Processing Record 24 of Set 10 | wakema
# Processing Record 25 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 10 | zhezkazgan
# Processing Record 28 of Set 10 | vestmannaeyjar
# Processing Record 29 of Set 10 | vysokogornyy
# Processing Record 30 of Set 10 | takoradi
# Processing Record 31 of Set 10 | trinidad
# Processing Record 32 of Set 10 | buala
# Processing Record 33 of Set 10 | henties bay
# Processing Record 34 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 10 | tocopilla
# Processing Record 36 of Set 10 | roma
# Processing Record 37 of Set 10 | fomboni
# Processing Record 38 of Set 10 | beringovskiy
# Processing Record 39 of Set 10 | gornopravdinsk
# Processing Record 40 of Set 10 | merrill
# Processing Record 41 of Set 10 | hami
# Processing Record 42 of Set 10 | mnogovershinnyy
# Processing Record 43 of Set 10 | krasnyy chikoy
# Processing Record 44 of Set 10 | kamaishi
# Processing Record 45 of Set 10 | portland
# Processing Record 46 of Set 10 | waipawa
# Processing Record 47 of Set 10 | morondava
# Processing Record 48 of Set 10 | kisangani
# Processing Record 49 of Set 10 | lincolnton
# Processing Record 50 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 1 of Set 11 | sakhon nakhon
# Processing Record 2 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 3 of Set 11 | biltine
# Processing Record 4 of Set 11 | bowen
# Processing Record 5 of Set 11 | san buenaventura
# Processing Record 6 of Set 11 | zhangjiakou
# Processing Record 7 of Set 11 | baykit
# Processing Record 8 of Set 11 | ocos
# Processing Record 9 of Set 11 | road town
# Processing Record 10 of Set 11 | wanaka
# Processing Record 11 of Set 11 | mahibadhoo
# Processing Record 12 of Set 11 | tahta
# Processing Record 13 of Set 11 | channel-port aux basques
# Processing Record 14 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 11 | necochea
# Processing Record 16 of Set 11 | inta
# Processing Record 17 of Set 11 | igarka
# Processing Record 18 of Set 11 | broome
# Processing Record 19 of Set 11 | okato
# Processing Record 20 of Set 11 | tessalit
# Processing Record 21 of Set 11 | qandala
# Processing Record 22 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 11 | roald
# Processing Record 24 of Set 11 | mecca
# Processing Record 25 of Set 11 | mahon
# Processing Record 26 of Set 11 | plouzane
# Processing Record 27 of Set 11 | ipixuna
# Processing Record 28 of Set 11 | manzanillo
# Processing Record 29 of Set 11 | mukdahan
# Processing Record 30 of Set 11 | klyuchi
# Processing Record 31 of Set 11 | olga
# Processing Record 32 of Set 11 | robe
# Processing Record 33 of Set 11 | komsomolskiy
# Processing Record 34 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 11 | mandera
# Processing Record 36 of Set 11 | inirida
# Processing Record 37 of Set 11 | somotillo
# Processing Record 38 of Set 11 | pochutla
# Processing Record 39 of Set 11 | muisne
# Processing Record 40 of Set 11 | aquiraz
# Processing Record 41 of Set 11 | anadyr
# Processing Record 42 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 43 of Set 11 | conde
# Processing Record 44 of Set 11 | razdolinsk
# Processing Record 45 of Set 11 | nantucket
# Processing Record 46 of Set 11 | ucluelet
# Processing Record 47 of Set 11 | malanje
# Processing Record 48 of Set 11 | kutum
# Processing Record 49 of Set 11 | flin flon
# Processing Record 50 of Set 11 | emirdag
# Processing Record 1 of Set 12 | camocim
# Processing Record 2 of Set 12 | klaksvik
# Processing Record 3 of Set 12 | new glasgow
# Processing Record 4 of Set 12 | snasa
# Processing Record 5 of Set 12 | sakakah
# Processing Record 6 of Set 12 | tonekabon
# Processing Record 7 of Set 12 | san cristobal
# Processing Record 8 of Set 12 | quatre cocos
# Processing Record 9 of Set 12 | bertoua
# Processing Record 10 of Set 12 | mpika
# Processing Record 11 of Set 12 | sabya
# Processing Record 12 of Set 12 | caxito
# Processing Record 13 of Set 12 | tokur
# Processing Record 14 of Set 12 | kapit
# Processing Record 15 of Set 12 | karlshamn
# Processing Record 16 of Set 12 | trojes
# Processing Record 17 of Set 12 | ambilobe
# Processing Record 18 of Set 12 | kang
# Processing Record 19 of Set 12 | binzhou
# Processing Record 20 of Set 12 | dabat
# Processing Record 21 of Set 12 | jacareacanga
# Processing Record 22 of Set 12 | jadu
# Processing Record 23 of Set 12 | les cayes
# Processing Record 24 of Set 12 | salgueiro
# Processing Record 25 of Set 12 | magistralnyy
# Processing Record 26 of Set 12 | ko samui
# Processing Record 27 of Set 12 | port-gentil
# Processing Record 28 of Set 12 | isangel
# Processing Record 29 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 12 | diavatos
# Processing Record 31 of Set 12 | le moule
# Processing Record 32 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 12 | rodas
# Processing Record 35 of Set 12 | bonnyville
# Processing Record 36 of Set 12 | kimberley
# Processing Record 37 of Set 12 | las vegas
# Processing Record 38 of Set 12 | havelock
# Processing Record 39 of Set 12 | bang saphan
# Processing Record 40 of Set 12 | montepuez
# Processing Record 41 of Set 12 | xam nua
# Processing Record 42 of Set 12 | dohrighat
# Processing Record 43 of Set 12 | qui nhon
# Processing Record 44 of Set 12 | cuamba
# Processing Record 45 of Set 12 | la sarre
# Processing Record 46 of Set 12 | damietta
# Processing Record 47 of Set 12 | kholodnyy
# Processing Record 48 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 12 | cervo
# Processing Record 50 of Set 12 | portel
# Processing Record 1 of Set 13 | russell
# Processing Record 2 of Set 13 | copiapo
# Processing Record 3 of Set 13 | sioux lookout
# Processing Record 4 of Set 13 | krasnoselkup
# Processing Record 5 of Set 13 | xichang
# Processing Record 6 of Set 13 | la ronge
# Processing Record 7 of Set 13 | wakkanai
# Processing Record 8 of Set 13 | chegdomyn
# Processing Record 9 of Set 13 | chicama
# Processing Record 10 of Set 13 | hirtshals
# Processing Record 11 of Set 13 | archidona
# Processing Record 12 of Set 13 | grand gaube
# Processing Record 13 of Set 13 | manggar
# Processing Record 14 of Set 13 | formosa
# Processing Record 15 of Set 13 | namatanai
# Processing Record 16 of Set 13 | juan lacaze
# Processing Record 17 of Set 13 | taksimo
# Processing Record 18 of Set 13 | palaikastron
# Processing Record 19 of Set 13 | esso
# Processing Record 20 of Set 13 | kondinskoye
# Processing Record 21 of Set 13 | los llanos de aridane
# Processing Record 22 of Set 13 | skagen
# Processing Record 23 of Set 13 | kloulklubed
# Processing Record 24 of Set 13 | piopio
# Processing Record 25 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 13 | kawambwa
# Processing Record 27 of Set 13 | srivardhan
# Processing Record 28 of Set 13 | brokopondo
# Processing Record 29 of Set 13 | bubaque
# Processing Record 30 of Set 13 | keti bandar
# Processing Record 31 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 13 | papillion
# Processing Record 33 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 13 | urulga
# City not found. Skipping...
# Processing Record 35 of Set 13 | fort-shevchenko
# Processing Record 36 of Set 13 | campbell river
# Processing Record 37 of Set 13 | atlantic city
# Processing Record 38 of Set 13 | saint-francois
# Processing Record 39 of Set 13 | wajima
# Processing Record 40 of Set 13 | karasuk
# Processing Record 41 of Set 13 | ambagarh chauki
# Processing Record 42 of Set 13 | eenhana
# Processing Record 43 of Set 13 | rafael reyes
# City not found. Skipping...
# Processing Record 44 of Set 13 | rio gallegos
# Processing Record 45 of Set 13 | mbandaka
# Processing Record 46 of Set 13 | balikpapan
# Processing Record 47 of Set 13 | salinas
# Processing Record 48 of Set 13 | emba
# Processing Record 49 of Set 13 | yeniseysk
# Processing Record 50 of Set 13 | excelsior springs
# Processing Record 1 of Set 14 | ayagoz
# Processing Record 2 of Set 14 | rampura
# Processing Record 3 of Set 14 | ciudad guayana
# Processing Record 4 of Set 14 | cairns
# Processing Record 5 of Set 14 | chipata
# Processing Record 6 of Set 14 | saint-joseph
# Processing Record 7 of Set 14 | sabi
# Processing Record 8 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 14 | anklam
# Processing Record 10 of Set 14 | nara
# Processing Record 11 of Set 14 | muros
# Processing Record 12 of Set 14 | marovoay
# Processing Record 13 of Set 14 | hurghada
# Processing Record 14 of Set 14 | marsaxlokk
# Processing Record 15 of Set 14 | bryan
# Processing Record 16 of Set 14 | mildura
# Processing Record 17 of Set 14 | tatawin
# Processing Record 18 of Set 14 | mount isa
# Processing Record 19 of Set 14 | guerrero negro
# Processing Record 20 of Set 14 | mountain home
# Processing Record 21 of Set 14 | parli
# Processing Record 22 of Set 14 | peniche
# Processing Record 23 of Set 14 | leningradskiy
# Processing Record 24 of Set 14 | razdolnoye
# Processing Record 25 of Set 14 | buckeye
# Processing Record 26 of Set 14 | armidale
# Processing Record 27 of Set 14 | cerritos
# Processing Record 28 of Set 14 | kupang
# Processing Record 29 of Set 14 | dublyany
# Processing Record 30 of Set 14 | burnie
# Processing Record 31 of Set 14 | saint-pierre
# Processing Record 32 of Set 14 | calvinia
# Processing Record 33 of Set 14 | saveh
# Processing Record 34 of Set 14 | letterkenny
# Processing Record 35 of Set 14 | paita
# Processing Record 36 of Set 14 | seoul
# Processing Record 37 of Set 14 | banamba
# Processing Record 38 of Set 14 | ciudad bolivar
# Processing Record 39 of Set 14 | teknaf
# Processing Record 40 of Set 14 | mantua
# Processing Record 41 of Set 14 | mahaicony
# City not found. Skipping...
# Processing Record 42 of Set 14 | ubinskoye
# Processing Record 43 of Set 14 | kargat
# Processing Record 44 of Set 14 | yarada
# Processing Record 45 of Set 14 | launceston
# Processing Record 46 of Set 14 | barcelos
# Processing Record 47 of Set 14 | san vicente
# Processing Record 48 of Set 14 | namibe
# Processing Record 49 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 14 | noumea
# Processing Record 1 of Set 15 | denpasar
# Processing Record 2 of Set 15 | beloha
# Processing Record 3 of Set 15 | huarmey
# Processing Record 4 of Set 15 | roela
# Processing Record 5 of Set 15 | mangan
# Processing Record 6 of Set 15 | puerto carreno
# Processing Record 7 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 8 of Set 15 | fort nelson
# Processing Record 9 of Set 15 | mokhsogollokh
# Processing Record 10 of Set 15 | newport
# Processing Record 11 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 15 | amga
# Processing Record 13 of Set 15 | socorro
# Processing Record 14 of Set 15 | sheltozero
# Processing Record 15 of Set 15 | acari
# Processing Record 16 of Set 15 | wattegama
# Processing Record 17 of Set 15 | nouakchott
# Processing Record 18 of Set 15 | tupik
# Processing Record 19 of Set 15 | sao geraldo do araguaia
# Processing Record 20 of Set 15 | shubarshi
# Processing Record 21 of Set 15 | junagarh
# Processing Record 22 of Set 15 | kailua
# Processing Record 23 of Set 15 | townsville
# Processing Record 24 of Set 15 | tilichiki
# Processing Record 25 of Set 15 | bayir
# Processing Record 26 of Set 15 | shu
# Processing Record 27 of Set 15 | northam
# Processing Record 28 of Set 15 | yeppoon
# Processing Record 29 of Set 15 | colwyn bay
# Processing Record 30 of Set 15 | morgantown
# Processing Record 31 of Set 15 | manaus
# Processing Record 32 of Set 15 | luganville
# Processing Record 33 of Set 15 | abnub
# Processing Record 34 of Set 15 | panacan
# Processing Record 35 of Set 15 | benguela
# Processing Record 36 of Set 15 | marystown
# Processing Record 37 of Set 15 | tselinnoye
# Processing Record 38 of Set 15 | asyut
# Processing Record 39 of Set 15 | radzyn podlaski
# Processing Record 40 of Set 15 | ulladulla
# Processing Record 41 of Set 15 | caravelas
# Processing Record 42 of Set 15 | kunya
# Processing Record 43 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 15 | porto novo
# Processing Record 45 of Set 15 | katakwi
# Processing Record 46 of Set 15 | narsaq
# Processing Record 47 of Set 15 | koraput
# Processing Record 48 of Set 15 | janesville
# Processing Record 49 of Set 15 | benjamin constant
# Processing Record 50 of Set 15 | jevargi
# Processing Record 1 of Set 16 | ingham
# Processing Record 2 of Set 16 | illimo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0   Port Elizabeth -33.9180   25.5701           clear sky     57.49        76
# 1           Albany  42.6001  -73.9662    scattered clouds     80.58        58
# 2           Hobart -42.8794  147.3294       broken clouds     52.27        95
# 3        Hithadhoo  -0.6000   73.0833          few clouds     81.95        74
# 4           Faanui -16.4833 -151.7500       moderate rain     76.23        81
# 5             Gaya  24.7833   85.0000     overcast clouds     81.97        76
# 6           Acarau  -2.8856  -40.1200    scattered clouds     78.40        76
# 7        Cape Town -33.9258   18.4232           clear sky     59.38        72
# 8  Arraial Do Cabo -22.9661  -42.0278           clear sky     71.56        83
# 9           Kodiak  57.7900 -152.4072     overcast clouds     57.79        71
#
#    Cloudiness  Wind Speed Country
# 0           0       17.27      ZA
# 1          27       10.45      US
# 2          75        0.00      AU
# 3          14        8.93      MV
# 4          33        9.69      PF
# 5          89        7.78      IN
# 6          50       16.58      BR
# 7           0        5.01      ZA
# 8           0       13.80      BR
# 9          98        1.57      US

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Elizabeth      ZA -33.9180   25.5701     57.49        76           0
# 1           Albany      US  42.6001  -73.9662     80.58        58          27
# 2           Hobart      AU -42.8794  147.3294     52.27        95          75
# 3        Hithadhoo      MV  -0.6000   73.0833     81.95        74          14
# 4           Faanui      PF -16.4833 -151.7500     76.23        81          33
# 5             Gaya      IN  24.7833   85.0000     81.97        76          89
# 6           Acarau      BR  -2.8856  -40.1200     78.40        76          50
# 7        Cape Town      ZA -33.9258   18.4232     59.38        72           0
# 8  Arraial Do Cabo      BR -22.9661  -42.0278     71.56        83           0
# 9           Kodiak      US  57.7900 -152.4072     57.79        71          98
#
#    Wind Speed Current Description
# 0       17.27           clear sky
# 1       10.45    scattered clouds
# 2        0.00       broken clouds
# 3        8.93          few clouds
# 4        9.69       moderate rain
# 5        7.78     overcast clouds
# 6       16.58    scattered clouds
# 7        5.01           clear sky
# 8       13.80           clear sky
# 9        1.57     overcast clouds

# %%
output_data_file = "/Users/tamir/Desktop/Class_Folder/Assignment/Assignment_6/Weather_Database/WeatherPy_Database.csv"

# %%
city_data_df.to_csv(output_data_file, index_label="City_ID")
